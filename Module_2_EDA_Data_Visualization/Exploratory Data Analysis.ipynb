# %% [markdown]
# ## **Data Setup**

# %%
# !pwd
# Out:
# /content

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !wget https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv
# Out:
# --2021-06-28 23:51:57--  https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3716 (3.6K) [text/plain]
# Saving to: ‘iris.csv.1’
#
# iris.csv.1          100%[===================>]   3.63K  --.-KB/s    in 0.001s
#
# 2021-06-28 23:51:57 (3.56 MB/s) - ‘iris.csv.1’ saved [3716/3716]

# %% [markdown]
# ## **Basic Questions**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load iris data to dataframe

iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# How many data points and features
print(iris.shape)
# Out:
# (150, 5)

# %%
# List of columns
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# How many data points per class?
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# ## **2-D Scatter Plot**

# %%
# 2D Scatter plot between Sepal length and Sepal Width
iris.plot(kind='scatter',x='sepal_length', y='sepal_width')
plt.grid()
plt.show()

# %%
# 2D Scatter plot with different colours on class

sns.set_style('whitegrid');
sns.FacetGrid(iris, hue='species', height=5) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show()

# %% [markdown]
# **Observation :**
#
# Using Sepal_length and Sepal_width , we can classify setosa. But other 2 classes cannot be classified using these 2 features

# %% [markdown]
# ## **Pair Plots**

# %%
# pair plot . for iris it can generate 6 unique pair plots of 4 variables
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue='species', height =3);
plt.show()

# %% [markdown]
# **Observations :**
# 1. Looking at pair plots, there are 3 plots which can be taken up for further study.
# 2. Sepal Length vs Petal Length, Sepal Length vs Petal Width and Petal length and petal Width.
# 3. On a closer look, Petal Length and Petal width will be the better one as it has vey less cross-over points when compared to other 2 plots.
# 4. We can classify using simple if-else model using Petal length and petal width to classify.

# %% [markdown]
# ## **Histogram, PDF and CDF**

# %%
## 1D Scatter Plot

iris_setosa = iris.loc[iris['species']=='setosa']
iris_versicolor = iris.loc[iris['species']=='versicolor']
iris_virginica = iris.loc[iris['species']=='virginica']

plt.plot(iris_setosa['petal_length'], np.zeros_like(iris_setosa['petal_length']),'.')
plt.plot(iris_versicolor['petal_length'], np.zeros_like(iris_versicolor['petal_length']),'.')
plt.plot(iris_virginica['petal_length'], np.zeros_like(iris_virginica['petal_length']),'.')

plt.show()

# %%
# Plot histogram
sns.FacetGrid(iris,hue='species',height=5) \
   .map(sns.distplot,'petal_length') \
   .add_legend();

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Plot histogram
sns.FacetGrid(iris,hue='species',height=5) \
   .map(sns.distplot,'petal_width') \
   .add_legend();

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Plot histogram
sns.FacetGrid(iris,hue='species',height=5) \
   .map(sns.distplot,'sepal_length') \
   .add_legend();

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Plot histogram
sns.FacetGrid(iris,hue='species',height=5) \
   .map(sns.distplot,'sepal_width') \
   .add_legend();

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Observations :
#
#  1. Petal Length is slightly bettter than Petal Width as there is clear separation of setosa and no overlaps
#  2. Petal Width is largley better than Sepal Length as Overlap is more on Sepal length.
#  3. Sepal Length is better than Sepal Width as overlap opn all 3 classes are more.
#  4. if we need to chose one variable , petal length will be the choice.
#  5. But combination of Petal length and Petal width is intresting one to study.

# %% [markdown]
# ## **CDF (Cumulative Density Functions)**

# %%
counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins =7, density=True)
print(counts)
print(bin_edges)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.06666667 0.26666667 0.2        0.73333333 0.66666667 1.
#  0.4       ]
# [3.  3.3 3.6 3.9 4.2 4.5 4.8 5.1]

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins =10, density=True)
print(counts)
print(bin_edges)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
#setosa
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


# virginica
counts, bin_edges = np.histogram(iris_virginica['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


#versicolor
counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)


plt.show();

# %% [markdown]
# ## **Mean, Variance and Std.Deviation**

# %%
print('Means:')
print('************************************')
print('Mean of Setosa :',np.mean(iris_setosa['petal_length']))
print('Mean of versicolor :',np.mean(iris_versicolor['petal_length']))
print('Mean of virginica :',np.mean(iris_virginica['petal_length']))

print('************************************')
print('Mean of Setosa with outlier :',np.mean(np.append(iris_setosa['petal_length'], 51)))
# Out:
# Means:
# ************************************
# Mean of Setosa : 1.464
# Mean of versicolor : 4.26
# Mean of virginica : 5.552
# ************************************
# Mean of Setosa with outlier : 2.435294117647059

# %%
print('Std Dev:')
print('**************************************')

print('Std Dev of Setosa :',np.std(iris_setosa['petal_length']))
print('Std Dev of Versicolor :',np.std(iris_versicolor['petal_length']))
print('Std Dev of Virginica :',np.std(iris_virginica['petal_length']))
# Out:
# Std Dev:
# **************************************
# Std Dev of Setosa : 0.17176728442867115
# Std Dev of Versicolor : 0.4651881339845204
# Std Dev of Virginica : 0.5463478745268441

# %% [markdown]
# ## **Median**

# %%
print('Median:')
print('************************************')
print('Median of Setosa :',np.median(iris_setosa['petal_length']))
print('Median of versicolor :',np.median(iris_versicolor['petal_length']))
print('Median of virginica :',np.median(iris_virginica['petal_length']))

print('************************************')
print('Mean of Setosa with outlier :',np.median(np.append(iris_setosa['petal_length'], 51)))
# Out:
# Median:
# ************************************
# Median of Setosa : 1.5
# Median of versicolor : 4.35
# Median of virginica : 5.55
# ************************************
# Mean of Setosa with outlier : 1.5

# %% [markdown]
# ## Percentiles and Quantile

# %%
print('Percentiles:')
print('************************************')

print('95th Percentile of setosa :', np.percentile(iris_setosa['petal_length'],95))
print('95th Percentile of versicolor :', np.percentile(iris_versicolor['petal_length'],95))
print('95th Percentile of virginica :', np.percentile(iris_virginica['petal_length'],95))

print('\nQuantiles:')
print('************************************')

print('Quantiles of setosa :', np.percentile(iris_setosa['petal_length'],np.arange(0,101,25)))
print('Quantiles of versicolor :', np.percentile(iris_versicolor['petal_length'],np.arange(0,101,25)))
print('Quantiles of virginica :', np.percentile(iris_virginica['petal_length'],np.arange(0,101,25)))
# Out:
# Percentiles:
# ************************************
# 95th Percentile of setosa : 1.7
# 95th Percentile of versicolor : 4.9
# 95th Percentile of virginica : 6.654999999999999
#
# Quantiles:
# ************************************
# Quantiles of setosa : [1.    1.4   1.5   1.575 1.9  ]
# Quantiles of versicolor : [3.   4.   4.35 4.6  5.1 ]
# Quantiles of virginica : [4.5   5.1   5.55  5.875 6.9  ]

# %% [markdown]
# ## **Median Absolute Deviation (MAD)**

# %%
from statsmodels import robust
print('Median Absolute Deviation:')

print('MAD of setosa :', robust.mad(iris_setosa['petal_length']))
print('MAD of versicolor :', robust.mad(iris_versicolor['petal_length']))
print('MAD of virginica :', robust.mad(iris_virginica['petal_length']))
# Out:
# Median Absolute Deviation:
# MAD of setosa : 0.14826022185056031
# MAD of versicolor : 0.5189107764769602
# MAD of virginica : 0.6671709983275211

# %% [markdown]
# ## **Box Plot with Whiskers**

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# ## **Violin Plot**

# %%
sns.violinplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# ## **Contour Plots**

# %%
sns.jointplot(x='petal_length', y='petal_width', data = iris_setosa,kind='kde')
plt.show()

# %% [markdown]
# ## **Bins**

# %%
import numpy as np

# consider you have an array like this

a= [1, 2, 3, 5, 10,11, 12, 13, 14, 15, 21,23, 25, 26, 27, 29, 30,31, 35, 51]

# here we have decided to group all these numbers into 5 bins

# i.e bins = 5

# the minimum number in the array is 1

# the maximum number in the array is 51

# the width of each bin is calculated as = ((max - min) / bins)

# width of each bin = (51-1)/5 = 10

# Since we got each bin with as 10, we can choose the bin edges like this

# 1 ...... 11 ....... 21 ........ 31 ....... 41 ....... 51

# |---10---|----10----|----10-----|----10----|----10----|

# so we have found out the bin edges now

# to find thte counts we calcuate how many number of points fall into each bin

# therefore the count of a bin = number of elements of a such that left_bin_egde<=a

# i 5 [1,2,3,5,10]

# ii. number of elements belongs to the 2nd bin 11<=x<21 => 5 [11,12,13,14,15]

# iii. number of elements belongs to the 3rd bin 21<=x<31 => 7 [21,23,25,26,27,29,30]

# iii. number of elements belongs to the 3rd bin 21<=x<31 => 7 [21,23,25,26,27,29,30]

# iv. number of elements belongs to the 4th bin 31<=x<41 => 2 [31,35]

# v. number of elements belongs to the 5th bin 41<=x<=51 => 1 [51]

# note: from the documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram.html

# All but the last (righthand-most) bin is half-open i.e [1,2,3,4], the bins are [1,2), [2,3), [3,4]

# [1,10) = 1,2,3,4,5,6,7,8,9 means includig 1 and but not 10. its half open bracket

print('='*30, "explaining 'bin edges and counts",'='*30)

counts,bins = np.histogram(a, bins=5)

print("bin edges :",bins)

print("counts per each bin :",counts)

# density: bool, optional

# If False, the result will contain the number of samples in each bin. 

# If True, the result is the value of the probability density function at the bin, normalized such that the integral over the range is 1. 

# Note that the sum of the histogram values will not be equal to 1 unless bins of unity width are chosen;

# it is not a probability mass function.

# and from the source code

#if density:

#        db = np.array(np.diff(bin_edges), float)

#        return n/db/n.sum(), bin_edges

# here the n => number of elements for each bin

n = counts

# and db = difference between bin edges

db = np.array(np.diff(bins))

print(counts)
print(db)

# n.sum() number of all the elemnts 

print('='*30, "explaining 'density=True' parameter",'='*30)

print("manual calculated densities for each bin",counts/db/counts.sum())

counts, bins = np.histogram(a, bins=5, density=True)

print("bin edges :",bins)

print("counts per each bin using density=True:",counts)

print('='*30, "explaining counts/sum(counts)",'='*30)

# pleasen note that the documentation says when you have density=True, 

# "that the sum of the histogram values will not be equal to 1"

# this is simple logic we used, to make the whole sum=1, we have divided each element by the number of whole elements

counts, bins = np.histogram(a, bins=5, density=True)

print("bin edges :",bins)

# sum(counts) = summ of all the elements in the counts array = [0.025 + 0.025 + 0.035 + 0.01 + 0.005] = 0.1

# counts/sum(counts) = devide every element of counts=[0.025/0.1, 0.025/0.1, 0.035/0.1, 0.01/0.1, 0.005/0.1] = [0.25 0.25 0.35 0.1  0.05]

print("counts per each bin using density=True:",counts/sum(counts))
# Out:
# ============================== explaining 'bin edges and counts ==============================
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin : [5 5 7 2 1]
# [5 5 7 2 1]
# [10. 10. 10. 10. 10.]
# ============================== explaining 'density=True' parameter ==============================
# manual calculated densities for each bin [0.025 0.025 0.035 0.01  0.005]
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin using density=True: [0.025 0.025 0.035 0.01  0.005]
# ============================== explaining counts/sum(counts) ==============================
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin using density=True: [0.25 0.25 0.35 0.1  0.05]
